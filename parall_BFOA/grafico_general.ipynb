# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\alan4\AppData\Local\Temp\ipykernel_12428\1492400551.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Cargar el archivo CSV
df = pd.read_csv("resultados_30_corridas.csv")  # Asegúrate de usar el nombre correcto del archivo

# %%
# Graficar Fitness vs Iteración
plt.figure(figsize=(10, 6))
for corrida, group in df.groupby(df.index // 3):  # Agrupar por corrida (3 iteraciones por corrida)
    plt.plot(group["Iteración"], group["Fitness"], marker="o", label=f"Corrida {corrida + 1}")

plt.xlabel("Iteración")
plt.ylabel("Fitness")
plt.title("Fitness vs Iteración")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Graficar Tiempo vs Iteración
plt.figure(figsize=(10, 6))
for corrida, group in df.groupby(df.index // 3):
    plt.plot(group["Iteración"], group["Tiempo"], marker="o", label=f"Corrida {corrida + 1}")

plt.xlabel("Iteración")
plt.ylabel("Tiempo (segundos)")
plt.title("Tiempo vs Iteración")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Graficar Interacción vs Iteración
plt.figure(figsize=(10, 6))
for corrida, group in df.groupby(df.index // 3):
    plt.plot(group["Iteración"], group["Interacción"], marker="o", label=f"Corrida {corrida + 1}")

plt.xlabel("Iteración")
plt.ylabel("Interacción")
plt.title("Interacción vs Iteración")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Graficar BLOSUM vs Iteración
plt.figure(figsize=(10, 6))
for corrida, group in df.groupby(df.index // 3):
    plt.plot(group["Iteración"], group["BLOSUM"], marker="o", label=f"Corrida {corrida + 1}")

plt.xlabel("Iteración")
plt.ylabel("BLOSUM")
plt.title("BLOSUM vs Iteración")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Crear una figura con subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
fig.suptitle("Métricas por Iteración y Corrida")

# Fitness vs Iteración
for corrida, group in df.groupby(df.index // 3):
    axes[0, 0].plot(group["Iteración"], group["Fitness"], marker="o", label=f"Corrida {corrida + 1}")
axes[0, 0].set_title("Fitness vs Iteración")
axes[0, 0].set_xlabel("Iteración")
axes[0, 0].set_ylabel("Fitness")
axes[0, 0].legend()
axes[0, 0].grid(True)

# Tiempo vs Iteración
for corrida, group in df.groupby(df.index // 3):
    axes[0, 1].plot(group["Iteración"], group["Tiempo"], marker="o", label=f"Corrida {corrida + 1}")
axes[0, 1].set_title("Tiempo vs Iteración")
axes[0, 1].set_xlabel("Iteración")
axes[0, 1].set_ylabel("Tiempo (segundos)")
axes[0, 1].legend()
axes[0, 1].grid(True)

# Interacción vs Iteración
for corrida, group in df.groupby(df.index // 3):
    axes[1, 0].plot(group["Iteración"], group["Interacción"], marker="o", label=f"Corrida {corrida + 1}")
axes[1, 0].set_title("Interacción vs Iteración")
axes[1, 0].set_xlabel("Iteración")
axes[1, 0].set_ylabel("Interacción")
axes[1, 0].legend()
axes[1, 0].grid(True)

# BLOSUM vs Iteración
for corrida, group in df.groupby(df.index // 3):
    axes[1, 1].plot(group["Iteración"], group["BLOSUM"], marker="o", label=f"Corrida {corrida + 1}")
axes[1, 1].set_title("BLOSUM vs Iteración")
axes[1, 1].set_xlabel("Iteración")
axes[1, 1].set_ylabel("BLOSUM")
axes[1, 1].legend()
axes[1, 1].grid(True)

# Ajustar el espacio entre subplots
plt.tight_layout()
plt.show()
